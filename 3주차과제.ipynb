# %% [markdown]
# <a href="https://colab.research.google.com/github/CheayeonLee/ESAA_YB2/blob/main/3%EC%A3%BC%EC%B0%A8%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04-1 데이터 시각화가 필요한 이유

# %% [markdown]
# ## 앤스콤 4분할 그래프 살펴보기

# %% [markdown]
# *   앤스콤 4분할 그래프: 데이터를 시각화하지 않고 수치만 확인할 때 발행할 수 있는 함정을 보여주기 위해 만든 그래프
# *   함정: 4개의 데이터 그룹은 각각 평균, 분산과 같은 수칫값이나 상관관계, 회귀선이 같은데, 이것만 보고 '데이터 그룹 1,2,3,4의 데이터는 모두 같을 것이다'라고 착각하는 것
# *   앤스콤 데이터 집합은 seaborn 라이브러리에 포함

# %% [markdown]
# ### 앤스콤 데이터 집합 불러온 후 그래프 그리기

# %%
import seaborn as sns

anscombe = sns.load_dataset('anscombe')
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# matplotlib 라이브러리 불러오기
#%matplotlib notebook #jupyter에서 외부창에 그래프 불러오고 싶을 때 사용
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset']=='I']

# %%
plt.plot(dataset_1['x'],dataset_1['y'])

# %%
plt.plot(dataset_1['x'],dataset_1['y'],'o')

# %% [markdown]
# ## 앤스콤 데이터 집합 모두 사용해 그래프 만들기

# %% [markdown]
# ### 한 번에 4개의 그래프 그리기

# %%
dataset_2 = anscombe[anscombe['dataset']=='II']
dataset_3 = anscombe[anscombe['dataset']=='III']
dataset_4 = anscombe[anscombe['dataset']=='IV']

# %%
# 격자가 위치할 기본 틀 생성
fig = plt.figure()
# 기본 틀에 격자를 추가: add_subplot(행크기, 열크기, 번호)
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
axes1.plot(dataset_1['x'],dataset_1['y'],'o')
axes2.plot(dataset_2['x'],dataset_2['y'],'o')
axes3.plot(dataset_3['x'],dataset_3['y'],'o')
axes4.plot(dataset_4['x'],dataset_4['y'],'o')
# fig를 써야 그래프가 나타남
fig

# %%
axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')

fig

# %%
fig.suptitle('Anscombe Data')

fig

# %%
fig.tight_layout()

fig

# %% [markdown]
# # 04-2 matplotlib 라이브러리 자유자재로 사용하기

# %% [markdown]
# ## 기초 그래프 그리기

# %% [markdown]
# *   히스토그램: 데이터프레임의 열 데이터 분포와 빈도를 살펴보는 용도
#
#
# >> 일변량 그래프: 변수를 하나만 사용해서 그린 그래프

# %% [markdown]
# *   산점도: 변수 2개를 사용해서 만드는 그래프
# >> 이변량 그래프: 변수 2개를 사용해서 그린 그래프

# %% [markdown]
# * 박스 그래프: 이산형 변수와 연속형 변수를 함께 사용하는 그래프

# %% [markdown]
# ### 기초 그래프 그리기-히스토그램, 산점도 그래프, 박스 그래프

# %%
tips = sns.load_dataset('tips')
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)

# %%
# hist 메서드를 이용해 히스토그램 그리기
# bins 인잣값으로 x축 간격 조정
axes1.hist(tips['total_bill'], bins=10)
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig

# %%
# scatter 메서드를 이용해 산점도 그리기기
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

# fig 안 해도 나옴
# Out:
# Text(0, 0.5, 'Tip')

# %%
# boxplot을 이용해 박스 그래프 그리기
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['sex']=='Female']['tip'],
              tips[tips['sex']=='Male']['tip']],
              labels=['Female','Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')

# fig 안 해도 나옴
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# ## 다변량 그래프 그리기

# %% [markdown]
# * 다변량 그래프: 3개 이상의 변수를 사용한 그래프
# * 다변량 그래프가 필요한 이유: 적재적소에 맞는 그래프 요소를 추가하여 그래프 표현해야 함
#
#      ex) 점 색상 다르게, 점 크기 다르게

# %% [markdown]
# ### 다변량 데이터로 다변량 그래프 그리기-산점도 그래프

# %%
def recode_sex(sex):
  if sex == 'Femae':
    return 0
  else:
    return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
# s: 점의 크기
# c: 점의 색상
# alpha: 투명도 조절

scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x = tips['total_bill'],
    y = tips['tip'],
    s = tips['size']*10,
    c = tips['sex_color'],
    alpha = 0.5)
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# # 04-3 seaborn 라이브러리 자유자재로 사용하기

# %% [markdown]
# *   count 그래프: 이산값을 나타낸 그래프

# %% [markdown]
# ### 단변량 그래프 그리기-히스토그램

# %%
import seaborn as sns

tips = sns.load_dataset('tips')

# %%
# distplot 메서드를 사용해 sns에서 히스토그램 그리기
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# <ipython-input-21-a33f1dea90e6>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'])
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
# 밀집도 그래프를 제외하고 싶은 경우 kde=False
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'],kde=False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <ipython-input-22-bc2ea51a3a75>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'],kde=False)
# Text(0, 0.5, 'Frequency')

# %%
# 밀집도 그래프만 나타내고 싶은 경우 hist = False
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'],hist=False)
ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit probability')
# Out:
# <ipython-input-23-1685672b37b4>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'],hist=False)
# Text(0, 0.5, 'Unit probability')

# %%
# 여러 그래프를 한 번에 출력하는 경우 rug = True
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'],rug=True)
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')
# Out:
# <ipython-input-24-7fb81ce81ff0>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tips['total_bill'],rug=True)
# Text(0.5, 0, 'Total Bill')

# %%
ax = plt.subplots()
ax = sns.countplot(x='day', data=tips) #이때 ('day', data=tips)라고 쓰면 오류가 나므로 x= 붙여줘야 함
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### 다양한 종류의 이변량 그래프 그리기

# %% [markdown]
# *  산점도 그리기: regplot 메서드

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# *   산점도 그래프와 히스토그램을 한 번에: jointplot 메서드

# %%
joint = sns.jointplot(x='total_bill',y='tip',data=tips)
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
joint = sns.jointplot(x='total_bill',y='tip',data=tips, kind="hex")
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# * 2차원 밀집도: kdeplot 메서드

# %%
ax = plt.subplot()
ax = sns.kdeplot(x=tips['total_bill'],
                 y=tips['tip'],
                 shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <ipython-input-30-c54bb652899c>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(x=tips['total_bill'],
# Text(0, 0.5, 'Tip')

# %% [markdown]
# * 바 그래프: barplot()

# %%
ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
# *   박스그래프: boxplot()

# %%
ax = plt.subplots()
ax = sns.boxplot(x='time',y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time',y='total_bill', data=tips)
ax.set_title('violin plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# * 관계 그래프 그리기: pairplot 메서드

# %%
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.displot, rug=True)
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### 다변량 그래프 그리기

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)

# %%
fig = sns.pairplot(tips, hue='sex')

# %%
# 산점도 그래프의 점 크기 조절
# scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','x'], scatter_kws={'s':tips['size']*10}) 은 오류가 나옴
# 해당 백터의 길이가 달라지기 때문: https://stackoverflow.com/questions/68457453/seaborn-lmplot-raises-valueerror-when-set-both-hue-and-scatter-kwss-s [참고]
scatter = sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','x'], size='size')

# %%
anscombe_plot = sns.lmplot(x='x',y='y', data=anscombe, fit_reg=False)

# %% [markdown]
# * col 인자: 데이터 그룹을 구분할 열 지정
# * col_wrap 인자: 그래프를 그릴 열의 최댓값 지정

# %%
# lmplot 메서드에 col, col_warp인자 설정해 그룹별로 그래프 그리기
anscombe_plot = sns.lmplot(x='x',y='y',data=anscombe, fit_reg=False, col='dataset', col_wrap=2)

# %% [markdown]
# ### FacetGrid 클래스로 그룹별 그래프 그리기

# %%
facet = sns.FacetGrid(tips, col='time')
facet.map(sns.displot, 'total_bill', rug=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.9/dist-packages/seaborn/distributions.py:2142: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex')
facet = facet.map(plt.scatter, 'total_bill','tip')
facet = facet.add_legend()

# %%
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex')
facet.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# #04-4 데이터프레임과 시리즈로 그래프 그리기

# %% [markdown]
# ### 데이터프레임과 시리즈로 그래프 그리기

# %% [markdown]
# * 히스토그램그리기

# %%
ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

# %%
# 투명도조절: alpha, bins, ax
fig, ax =plt.subplots()
ax = tips[['total_bill','tip']].plot.hist(alpha=0.5,bins=20, ax=ax)

# %%
# 밀집도
ax = plt.subplots()
ax = tips['tip'].plot.kde()

# %%
# 산점도
fig, ax = plt.subplots()
ax = tips.plot.scatter(x='total_bill',y='tip', ax=ax)
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# 육각형 그래프
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill',y='tip', ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill',y='tip', gridsize=10,ax=ax)

# %%
# box그래프
fig, ax = plt.subplots()
ax = tips.plot.box(ax=ax)

# %% [markdown]
# # 04-5 seaborn 라리브러리로 그래프 스타일 설정하기

# %% [markdown]
# ### 그래프에 스타일 적용하기

# %%
fig, ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %% [markdown]
# * whitegrid로 스타일 설정하여 그래프의 배경에 가로 줄 만들 수 있음

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots()
ax = sns.violinplot(x='time',y='total_bill', hue='sex', data=tips, split=True)

# %%
fig = plt.figure( )

seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']

for idx, style in enumerate(seaborn_styles):
  plot_position = idx + 1
  with sns.axes_style(style):
    ax = fig.add_subplot(2, 3, plot_position)
    violin = sns.violinplot(x='time' ,y='total_bill', data=tips,ax=ax)
    violin.set_title(style)
    
fig.tight_layout()
